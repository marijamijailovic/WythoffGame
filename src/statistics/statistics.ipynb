# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
calculate_time_n = pd.read_csv('./csv/calculate_time_n.csv')
calculate_time_n
# Out:
#            n  рекурзивна  алгебарска  аритметичка
# 0         10       0.022       0.009        0.106
# 1         20       0.023       0.014        0.175
# 2         40       0.038       0.018        0.397
# 3         80       0.069       0.019        0.801
# 4        160       0.110       0.033        1.718
# 5        320       0.212       0.045        3.702
# 6        640       0.398       0.085        7.224
# 7       1280       0.764       0.154       13.491
# 8       2560       1.559       0.313       18.112
# 9       5120       2.969       0.575       31.190
# 10     10240       5.446       1.223       63.070
# 11     20480      11.533       2.325      130.527
# 12     40960      19.007       4.733      274.890
# 13     81920      29.549       6.898      577.927
# 14    163840      38.508      11.908     1212.630
# 15    327680      77.360      23.227     2531.220
# 16    655360     154.610      46.643     5276.950
# 17   1310720     310.208      92.360    11054.600
# ...

# %%
calculate_piles = pd.read_csv('./csv/calculate_piles.csv')
calculate_piles
# Out:
#                                   n                                A  \
# 0                                10                               14
# 1                                20                               28
# 2                                40                               56
# 3                                80                              113
# 4                               160                              226
# 5                               320                              452
# 6                               640                              905
# 7                              1280                             1810
# 8                              2560                             3620
# 9                              5120                             7240
# 10                            10240                            14481
# 11                            20480                            28963
# 12                            40960                            57926
# ...

# %%
plt.figure(figsize=(1000/100,400/100), dpi=100);
plt.plot(calculate_time_n['n'], calculate_time_n['рекурзивна'], color='blue')
plt.title('График рекурзивне стратегије за конструкцију табеле изгзбљених позиција')
plt.xlabel('n, a = 2')
plt.ylabel('Време извршавања(ms)')
plt.grid(True)
plt.annotate('max pair (59 316 416, 143 202 496)', xy=(41885550, 10052.7), xytext=(34385550, 6500),
             arrowprops=dict(facecolor='blue', shrink=0.05),
             )
plt.savefig('./picture/recursive.png', dpi=100)
plt.show()

# %%
plt.figure(figsize=(1000/100,400/100), dpi=100);
plt.plot(calculate_time_n['n'], calculate_time_n['алгебарска'], color='red')
plt.title('График алгебарске стратегије за конструкцију табеле изгзбљених позиција')
plt.xlabel('n, a = 2')
plt.ylabel('Време извршавања(ms)')
plt.grid(True)
plt.annotate('max pair (59 316 416, 143 202 496)', xy=(41885550, 3065.81), xytext=(34385550, 2100),
             arrowprops=dict(facecolor='red', shrink=0.05),
             )
plt.savefig('./picture/algebraic.png', dpi=100)
plt.show()

# %%
plt.figure(figsize=(1000/100,400/100), dpi=100);
plt.plot(calculate_time_n['n'], calculate_time_n['аритметичка'], color='green')
plt.title('График аритметичке стратегије за конструкцију табеле изгзбљених позиција')
plt.xlabel('n, a = 2')
plt.ylabel('Време извршавања(ms)')
plt.grid(True)
plt.annotate('max pair (59 316 416, 143 202 496)', xy=(41885550, 587616), xytext=(34385550, 410000),
             arrowprops=dict(facecolor='green', shrink=0.05),
             )
plt.savefig('./picture/arithmetic.png', dpi=100)
plt.show()

# %%
plt.figure(figsize=(1000/100,400/100), dpi=100);
plt.plot(calculate_time_n['n'],calculate_time_n['рекурзивна'],color='blue')
plt.plot(calculate_time_n['n'],calculate_time_n['алгебарска'],color='red')
plt.plot(calculate_time_n['n'],calculate_time_n['аритметичка'],color='green')
plt.legend()
plt.title('Сумиран приказ извршавања свих стратегија за конструкцију табеле изгзбљених позиција')
plt.xlabel('n, a = 2')
plt.ylabel('Време извршавања(ms)')
plt.grid(True)
plt.savefig('./picture/all.png', dpi=100)
plt.show()

# %%
plt.figure(figsize=(1000/100,400/100), dpi=100);
plt.plot(calculate_time_n['n'],calculate_time_n['рекурзивна'],color='blue')
plt.plot(calculate_time_n['n'],calculate_time_n['алгебарска'],color='red')
plt.legend()
plt.title('Сумиран приказ извршавања рекурзивне и алгебарске стратегије за конструкцију табеле изгзбљених позиција')
plt.xlabel('n, a = 2')
plt.ylabel('Време извршавања(ms)')
plt.grid(True)
plt.savefig('./picture/algebraicVSrecursive.png', dpi=100)
plt.show()

# %%
calculate_time_a = pd.read_csv('./csv/calculate_time_a.csv')
calculate_time_a.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-3de1cbf8a074> in <module>
# ----> 1 calculate_time_a = pd.read_csv('./csv/calculate_time_a.csv')
#       2 calculate_time_a.info()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
calculate_time_a

# %%
plt.figure(figsize=(1000/100,400/100), dpi=100);
plt.plot(calculate_time_a['a'],calculate_time_a['algebraic'],color='red')
plt.plot(calculate_time_a['a'],calculate_time_a['arithmetic'],color='green')
plt.legend()
plt.title('Сумиран приказ извршавања алгебарске и аритметичке стратегије')
plt.xlabel('a, n = 100000')
plt.ylabel('Vreme izvrsavanja(ms)')
plt.grid(True)
plt.savefig('./picture/algebric_vs_arithmetic_a.png', dpi=100)
plt.show()
